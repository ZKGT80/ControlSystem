# %%
from openai import OpenAI
from langchain_community.chat_message_histories import ChatMessageHistory

# 1. Connect to LM Studio local server
client = OpenAI(
    base_url="http://127.0.0.1:1234/v1",
    api_key="lm-studio"  # any string works
)

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from openai import OpenAI

# Connect to LM Studio
client = OpenAI(
    base_url="http://127.0.0.1:1234/v1",
    api_key="lm-studio"
)

# Create chat history
history = ChatMessageHistory()

print("Chat started! Type 'exit' in the input box to stop.\n")

while True:

    query = input("User (Type 'exit' to quit): ")

    # Exit
    if query.lower() == "exit":
        print("\nExiting...")
        break

    # Ignore empty input
    if not query.strip():
        continue

    print("\nUser:", query)
    print("-" * 80)

    # Save user message
    history.add_user_message(query)

    # Convert history to OpenAI format
    messages_with_history = []

    for m in history.messages:
        role = "user" if m.type == "human" else "assistant"

        messages_with_history.append({
            "role": role,
            "content": m.content
        })

    try:
        # Send request to LM Studio
        stream = client.chat.completions.create(
            model="qwen/qwen3-1.7b",
            messages=messages_with_history,
            stream=True
        )

        full_ai_response = ""

        print("AI: ", end="", flush=True)

        # Stream response
        for chunk in stream:

            if hasattr(chunk.choices[0].delta, "content"):

                content = chunk.choices[0].delta.content

                if content is not None:
                    print(content, end="", flush=True)
                    full_ai_response += content

        # Save AI response
        history.add_ai_message(full_ai_response)

        print("\n")
        print("=" * 80)
        

    except Exception as e:
        print("\nERROR:", e)
# Out:
# Chat started! Type 'exit' in the input box to stop.
#
#
# User: Hello I'm Zyrus
# --------------------------------------------------------------------------------
# AI: Hello Zyrus! How can I assist you today? If you have any questions or need help with something, feel free to ask.
#
# ================================================================================
#
# User: What do I do in every day
# --------------------------------------------------------------------------------
# AI: In order to maximize your productivity and well-being, it's essential to establish a daily routine. Here are some suggestions for activities you could incorporate into your daily schedule:
#
# 1. Wake up at the same time every day: This helps regulate your sleep-wake cycle and can improve overall health.
#
# 2. Morning hygiene: Take care of personal grooming, such as brushing your teeth, washing your face, and getting dressed.
#
# 3. Exercise or physical activity: Engage in at least 30 minutes of exercise daily to maintain your physical fitness and well-being.
#
# 4. Breakfast: A healthy meal will give you the energy needed for the day ahead.
#
# 5. Plan your day: Review your schedule, set goals, and prioritize tasks.
#
# 6. Work or study: Dedicate a specific block of time to complete work or study-related tasks. Take breaks as needed to maintain focus and avoid burnout.
#
# 7. Social interaction: Connect with friends, family, or colleagues either in person or through digital communication channels.
#
# 8. Lunch break: Enjoy a balanced meal and take some time to relax during this period.
#
# 9. Hobbies and interests: Engage in activities that you enjoy, such as reading, crafting, or playing an instrument.
#
# 10. Personal development: Spend 15-30 minutes learning something new or practicing self-improvement skills like meditation or journaling.
#
# 11. Evening hygiene: Prepare for bed by removing makeup, washing your face, and getting ready for sleep.
#
# 12. Wind-down time: Engage in a calming activity before going to bed, such as reading, listening to soothing music, or taking a warm bath.
#
# Remember, it's essential to maintain a balance between work, leisure, and self-care activities. Adjust the schedule according to your lifestyle and preferences. Also, don't forget to get adequate sleep (7-9 hours) every day for optimal health and well-being.
#
# ================================================================================
#
# User: Tell me two things about microprocessor
# --------------------------------------------------------------------------------
# AI: A microprocessor is a computer chip that contains all the essential components of a processor on a single integrated circuit. It's designed to execute instructions in a sequential manner, making it an ideal choice for building small computers and other electronic devices. Here are two key aspects of microprocessors:
#
# 1. Architecture: Microprocessors have a well-defined architecture consisting of various functional units, such as the arithmetic logic unit (ALU), control unit, registers, cache memory, input/output (I/O) interfaces, and more. The ALU performs arithmetic and logical operations on data, while the control unit manages the flow of instructions by fetching, decoding, and executing them.
#
# 2. Instruction set: Microprocessors have a specific instruction set that determines the types of operations and functions they can perform. These instructions are designed to carry out basic tasks like addition, subtraction, bitwise operations, memory access, and data manipulation. Each microprocessor has its unique instruction set architecture (ISA), which may vary between different manufacturers and generations of processors.
#
# Microprocessors play a crucial role in modern technology by powering various devices such as computers, smartphones, tablets, gaming consoles, and more. Their widespread adoption has led to the development of complex multi-core processors that offer improved performance and power efficiency for a wide range of applications.
#
# ================================================================================
#
# User: escape
# --------------------------------------------------------------------------------
# AI: It seems like you want to escape from something or perhaps discuss an escape plan. Can you provide more context or detail about what you'd like to escape? If it's related to a specific situation, I'll do my best to help you find a suitable solution or strategy for moving forward.
#
# ================================================================================
#
# Exiting...
